# %%
class Node:
    """Node class for linked list."""
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularQueueLinkedList:
    def __init__(self):
        self.front = None
        self.rear = None

    def is_empty(self):
        return self.front is None

    def enqueue(self, item):
        new_node = Node(item)
        if self.is_empty():
            self.front = new_node
            self.rear = new_node
            new_node.next = self.front  # Point to itself
        else:
            self.rear.next = new_node
            new_node.next = self.front
            self.rear = new_node

# %%
class CircularQueueList:
    def __init__(self, size):
        self.size = size
        self.queue = []
        self.front = 0
        self.rear = 0

    def is_full(self):
        return len(self.queue) == self.size

    def is_empty(self):
        return len(self.queue) == 0

    def enqueue(self, item):
        if self.is_full():
            print("Queue is full!")
            return
        self.queue.append(item)
        self.rear = (self.rear + 1) % self.size

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        item = self.queue[self.front]
        self.front = (self.front + 1) % self.size
        return item

    def display(self):
        if self.is_empty():
            print("Queue is empty!")
            return
        for i in range(len(self.queue)):
            print(self.queue[(self.front + i) % self.size], end=" ")
        print()

# Example usage
if __name__ == "__main__":
    cq_list = CircularQueueList(5)
    cq_list.enqueue(10)
    cq_list.enqueue(20)
    cq_list.enqueue(30)
    cq_list.enqueue(40)
    cq_list.enqueue(50)
    cq_list.display()  # Display the queue

    print("Dequeued:", cq_list.dequeue())
    cq_list.display()  # Display the queue after dequeuing

    cq_list.enqueue(60)  # This should fail as the queue is full
    cq_list.display()
# Out:
# 10 20 30 40 50
# Dequeued: 10
# 20 30 40 50 10
# Queue is full!
# 20 30 40 50 10

# %%
class CircularQueueArray:
    def __init__(self, size):
        self.size = size
        self.queue = [None] * size
        self.front = -1
        self.rear = -1

    def is_full(self):
        return (self.rear + 1) % self.size == self.front

    def is_empty(self):
        return self.front == -1

    def enqueue(self, item):
        if self.is_full():
            print("Queue is full!")
            return
        if self.is_empty():
            self.front = 0
        self.rear = (self.rear + 1) % self.size
        self.queue[self.rear] = item

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        item = self.queue[self.front]
        if self.front == self.rear:  # Queue has only one element
            self.front = -1
            self.rear = -1
        else:
            self.front = (self.front + 1) % self.size
        return item

    def display(self):
        if self.is_empty():
            print("Queue is empty!")
            return
        i = self.front
        while True:
            print(self.queue[i], end=" ")
            if i == self.rear:
                break
            i = (i + 1) % self.size
        print()

# Example usage
if __name__ == "__main__":
    cq_array = CircularQueueArray(5)
    cq_array.enqueue(10)
    cq_array.enqueue(20)
    cq_array.enqueue(30)
    cq_array.enqueue(40)class CircularQueueArray:
    def __init__(self, size):
        self.size = size
        self.queue = [None] * size
        self.front = -1
        self.rear = -1

    def is_full(self):
        return (self.rear + 1) % self.size == self.front

    def is_empty(self):
        return self.front == -1

    def enqueue(self, item):
        if self.is_full():
            print("Queue is full!")
            return
        if self.is_empty():
            self.front = 0
        self.rear = (self.rear + 1) % self.size
        self.queue[self.rear] = item

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        item = self.queue[self.front]
        if self.front == self.rear:  # Queue has only one element
            self.front = -1
            self.rear = -1
        else:
            self.front = (self.front + 1) % self.size
        return item

    def display(self):
        if self.is_empty():
            print("Queue is empty!")
            return
        i = self.front
        while True:
            print(self.queue[i], end=" ")
            if i == self.rear:
                break
            i = (i + 1) % self.size
        print()

# Example usage
if __name__ == "__main__":
    cq_array = CircularQueueArray(5)
    cq_array.enqueue(10)
    cq_array.enqueue(20)
    cq_array.enqueue(30)
    cq_array.enqueue(40)
    cq_array.enqueue(50)
    cq_array.display()  # Display the queue

    print("Dequeued:", cq_array.dequeue())
    cq_array.display()  # Display the queue after dequeuing

    cq_array.enqueue(60)  # This should fail as the queue is full
    cq_array.display()

    cq_array.enqueue(50)
    cq_array.display()  # Display the queue

    print("Dequeued:", cq_array.dequeue())
    cq_array.display()  # Display the queue after dequeuing

    cq_array.enqueue(60)  # This should fail as the queue is full
    cq_array.display()
# Out:
# 10 20 30 40 50
# Dequeued: 10
# 20 30 40 50
# 20 30 40 50 60
